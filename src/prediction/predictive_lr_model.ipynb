# %%
import pandas as pd

# Importing data file for positive trafficking examples
pos_file = '/dfs/scratch0/jdunnmon/data/memex-data/predictive_model/trafficking_docs.tsv'
neg_file = '/dfs/scratch0/jdunnmon/data/memex-data/predictive_model/trafficking_docs_neg.tsv'

# Positive file dataframe
pos_df = pd.read_csv(pos_file,'\t')
neg_df = pd.read_csv(neg_file,'\t')

# %%
tot_df = pos_df.append(neg_df).reset_index()

# %%
# Creating dataframe with dummy variables for regression
explanatory_vars = ['area_code','weekday','domain']
df_dummies = pd.get_dummies(tot_df, columns=['incall_outcall','ethnicity','hour']+explanatory_vars)
#X = df_dummies.drop(['doc_id', 'trafficking'], axis=1).values
#tot_df = tot_df.drop(['domain','hour','weekday','area_code'],axis=1)
#df_dummies = pd.get_dummies(tot_df, columns=['incall_outcall','ethnicity'])
df_dummies = df_dummies.drop(['doc_id', 'trafficking','index'],axis=1)
df_dummies['price_hour'] = df_dummies['price_hour']/100
df_dummies['price_half_hour'] = df_dummies['price_half_hour']/100
X = df_dummies.values
y = tot_df['trafficking'].values

# %%
from sklearn.model_selection import train_test_split

# Splitting for train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=50)

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
classifier.score(X_test, y_test)
# Out:
# 0.92991631799163177

# %%
import numpy as np
coef = classifier.coef_[0]
coef_args = np.argsort(np.abs(coef))[::-1]
num_vars = len(coef)
top_vars = [df_dummies.keys()[coef_args[a]] for a in range(num_vars)]

# %%
for a,b in enumerate(top_vars):
    print(f"{top_vars[a]}: {coef[coef_args][a]:.4f}")
# Out:
# area_code_0: -5.0627
# area_code_616: 3.9462
# domain_escortsinthe.com: -3.8292
# domain_myproviderguide.com: 3.8251
# weekday_Thursday: -3.2969
# area_code_208: 3.2450
# area_code_775: 3.1681
# domain_liveescortreviews.com: -3.0850
# area_code_214: 3.0473
# area_code_312: 3.0244
# weekday_Tuesday: -2.6804
# area_code_972: 2.4946
# area_code_423: 2.4824
# weekday_Saturday: 2.4234
# weekday_Sunday: 2.3992
# area_code_773: 2.3851
# area_code_316: 2.3618
# weekday_Friday: 2.3274
# weekday_Wednesday: -2.3236
# domain_eroticmugshots.com: 2.2483
# area_code_281: 2.2470
# area_code_614: 2.2370
# area_code_410: 2.1766
# area_code_540: 2.1657
# area_code_424: 2.1335
# weekday_Monday: 2.1314
# area_code_954: 2.1245
# area_code_216: 2.1083
# area_code_231: 2.0726
# area_code_630: 2.0545
# area_code_404: 2.0529
# area_code_719: 2.0303
# area_code_678: 2.0057
# area_code_313: 2.0037
# area_code_302: 1.9543
# area_code_636: 1.9193
# domain_massagetroll.com: 1.7902
# area_code_505: 1.7404
# area_code_985: 1.6206
# area_code_336: 1.5893
# area_code_570: 1.5668
# area_code_647: -1.5647
# area_code_817: 1.5300
# area_code_919: 1.5258
# area_code_801: -1.5112
# area_code_716: 1.4872
# area_code_339: 1.4688
# area_code_347: -1.4674
# area_code_267: -1.4240
# domain_asexyservice.com: -1.3589
# area_code_226: -1.3493
# area_code_714: -1.3491
# area_code_810: -1.3408
# area_code_239: 1.3305
# area_code_918: -1.3101
# area_code_303: 1.2960
# area_code_613: -1.2952
# area_code_510: -1.2878
# area_code_646: -1.2858
# area_code_915: 1.2836
# area_code_980: 1.2611
# area_code_516: -1.2548
# area_code_206: -1.2517
# area_code_240: 1.2341
# area_code_704: 1.2259
# area_code_604: -1.2256
# area_code_503: 1.2036
# area_code_215: -1.1907
# area_code_480: 1.1806
# area_code_513: 1.1721
# area_code_334: -1.1713
# area_code_248: 1.1600
# area_code_888: 1.1559
# area_code_617: 1.1336
# area_code_757: 1.1304
# area_code_289: -1.1206
# area_code_706: 1.1017
# area_code_859: -1.0968
# area_code_416: -1.0939
# area_code_804: 1.0892
# area_code_205: 1.0750
# area_code_517: -1.0619
# area_code_470: 1.0542
# area_code_514: -1.0443
# area_code_213: -1.0440
# area_code_587: -1.0389
# area_code_708: 1.0372
# area_code_812: 1.0360
# area_code_808: -1.0303
# area_code_631: -1.0273
# area_code_601: -1.0227
# area_code_661: 1.0160
# area_code_978: -1.0153
# area_code_901: 1.0107
# area_code_818: -1.0102
# area_code_515: 1.0035
# area_code_701: -1.0020
# area_code_912: 1.0015
# area_code_984: -0.9837
# area_code_256: 0.9798
# area_code_209: -0.9755
# area_code_562: -0.9707
# domain_backpage.com: 0.9690
# price_half_hour: 0.9681
# area_code_212: -0.9582
# area_code_307: 0.9411
# area_code_360: -0.9343
# area_code_323: -0.9341
# area_code_330: 0.9287
# area_code_718: -0.9274
# area_code_484: -0.9273
# area_code_732: -0.9257
# area_code_612: -0.9228
# area_code_929: -0.9196
# area_code_304: -0.9186
# area_code_559: 0.9089
# area_code_412: -0.9036
# area_code_305: -0.9014
# area_code_403: -0.8999
# area_code_585: 0.8949
# area_code_602: -0.8917
# area_code_571: -0.8915
# area_code_478: 0.8914
# area_code_609: -0.8905
# hour_morning: 0.8852
# area_code_713: 0.8788
# area_code_504: -0.8768
# area_code_702: -0.8740
# area_code_715: -0.8630
# area_code_904: 0.8615
# area_code_786: 0.8470
# area_code_920: -0.8329
# area_code_937: 0.8273
# area_code_909: -0.8272
# area_code_603: -0.8230
# area_code_956: -0.8171
# area_code_770: 0.8131
# area_code_346: -0.8112
# domain_backpage.ca: 0.8014
# area_code_204: -0.7875
# area_code_832: 0.7795
# area_code_843: 0.7725
# area_code_608: -0.7539
# area_code_580: -0.7516
# area_code_586: 0.7365
# area_code_872: 0.7236
# area_code_816: 0.7224
# hour_afternoon: -0.7208
# area_code_16: -0.7107
# area_code_310: -0.7084
# area_code_337: 0.7074
# ethnicity_white: 0.7033
# area_code_250: -0.7029
# area_code_518: -0.7023
# area_code_519: -0.6988
# area_code_814: -0.6979
# area_code_309: 0.6977
# area_code_509: -0.6965
# area_code_800: -0.6934
# area_code_506: -0.6872
# area_code_529: -0.6841
# area_code_651: 0.6818
# area_code_863: -0.6817
# area_code_438: -0.6744
# area_code_202: 0.6724
# area_code_845: -0.6708
# area_code_916: -0.6705
# area_code_435: 0.6704
# area_code_815: 0.6684
# area_code_501: -0.6530
# area_code_440: 0.6450
# area_code_754: -0.6401
# area_code_270: -0.6389
# domain_cityvibe.com: 0.6275
# area_code_870: -0.6255
# area_code_847: -0.6241
# area_code_831: -0.6218
# area_code_425: -0.6215
# area_code_461: -0.6154
# area_code_781: 0.6058
# area_code_760: -0.6014
# area_code_618: -0.6001
# area_code_512: 0.5989
# area_code_703: -0.5971
# area_code_317: -0.5906
# area_code_641: 0.5749
# area_code_434: -0.5746
# area_code_720: 0.5743
# area_code_163: -0.5684
# area_code_780: -0.5678
# area_code_607: -0.5640
# hour_night: 0.5576
# area_code_772: -0.5545
# area_code_460: -0.5433
# area_code_813: -0.5417
# area_code_574: -0.5372
# area_code_507: -0.5310
# ethnicity_black: 0.5307
# area_code_76: -0.5278
# area_code_971: -0.5171
# area_code_805: -0.5154
# area_code_850: -0.5067
# area_code_941: -0.4999
# area_code_877: -0.4994
# area_code_858: -0.4981
# area_code_468: -0.4931
# area_code_466: -0.4885
# area_code_217: 0.4788
# area_code_865: -0.4775
# area_code_224: 0.4755
# area_code_431: -0.4749
# area_code_626: 0.4624
# area_code_269: 0.4601
# area_code_315: -0.4599
# area_code_443: 0.4579
# area_code_375: -0.4562
# area_code_682: 0.4500
# area_code_629: -0.4452
# area_code_530: 0.4429
# incall_outcall_in: 0.4415
# area_code_401: -0.4407
# area_code_606: -0.4259
# area_code_385: -0.4251
# area_code_949: -0.4229
# area_code_561: -0.4216
# area_code_520: -0.4200
# area_code_55: -0.4186
# ethnicity_asian: -0.4154
# area_code_320: -0.4112
# area_code_965: -0.4081
# area_code_724: -0.4062
# area_code_417: -0.4032
# area_code_306: -0.4009
# area_code_251: -0.3908
# area_code_475: -0.3877
# area_code_913: -0.3818
# area_code_740: -0.3741
# area_code_477: -0.3729
# area_code_725: -0.3692
# area_code_856: -0.3662
# area_code_778: -0.3661
# area_code_407: -0.3630
# area_code_763: -0.3629
# area_code_914: 0.3622
# area_code_951: -0.3601
# area_code_900: -0.3596
# area_code_765: -0.3587
# area_code_787: -0.3548
# area_code_419: -0.3544
# area_code_508: -0.3543
# area_code_541: 0.3540
# area_code_479: -0.3499
# area_code_619: -0.3498
# area_code_917: -0.3464
# area_code_164: -0.3420
# area_code_747: -0.3389
# area_code_970: 0.3363
# area_code_252: -0.3356
# area_code_409: 0.3326
# domain_escortsincollege.com: -0.3323
# area_code_864: -0.3321
# area_code_727: -0.3288
# area_code_610: -0.3212
# area_code_314: -0.3203
# area_code_615: 0.3174
# domain_naughtyreviews.com: -0.3172
# incall_outcall_0: 0.3113
# area_code_405: -0.3108
# area_code_698: -0.3081
# area_code_321: -0.3078
# area_code_415: -0.3068
# area_code_201: -0.3064
# area_code_469: 0.3057
# area_code_408: -0.3030
# price_hour: 0.3002
# area_code_940: 0.2971
# area_code_908: -0.2951
# area_code_352: -0.2937
# area_code_705: -0.2905
# incall_outcall_both: 0.2899
# area_code_301: -0.2870
# area_code_228: -0.2861
# area_code_712: -0.2819
# area_code_563: -0.2752
# area_code_526: -0.2690
# area_code_848: -0.2686
# area_code_709: -0.2673
# area_code_806: -0.2639
# hour_graveyard: 0.2586
# area_code_828: 0.2579
# area_code_53: -0.2577
# area_code_491: -0.2577
# ethnicity_latin: 0.2527
# area_code_246: -0.2519
# area_code_254: -0.2519
# area_code_717: -0.2518
# area_code_331: -0.2514
# area_code_979: -0.2509
# area_code_437: -0.2468
# area_code_17: -0.2464
# area_code_319: -0.2386
# area_code_72: -0.2340
# area_code_989: 0.2331
# area_code_402: -0.2324
# area_code_925: -0.2238
# area_code_210: -0.2219
# area_code_432: -0.2211
# area_code_253: -0.2201
# area_code_905: -0.2149
# area_code_218: -0.2121
# area_code_406: -0.2092
# area_code_650: -0.2065
# area_code_260: -0.2063
# area_code_575: -0.2009
# area_code_876: -0.1921
# area_code_857: 0.1716
# area_code_844: -0.1685
# domain_rubads.com: -0.1619
# area_code_910: 0.1606
# area_code_175: -0.1589
# area_code_474: -0.1566
# area_code_343: -0.1543
# area_code_662: -0.1504
# area_code_414: 0.1491
# area_code_14: -0.1487
# domain_adultsearch.com: 0.1472
# area_code_907: -0.1452
# area_code_567: -0.1448
# area_code_262: 0.1435
# area_code_450: -0.1408
# area_code_376: -0.1388
# area_code_734: 0.1378
# area_code_502: 0.1376
# area_code_525: -0.1308
# area_code_531: -0.1292
# area_code_973: -0.1265
# area_code_318: 0.1140
# area_code_782: -0.1128
# area_code_188: -0.1116
# area_code_207: 0.1108
# area_code_830: -0.1091
# area_code_860: -0.1090
# area_code_785: -0.1068
# domain_escortsin.com: -0.1064
# area_code_242: -0.1058
# area_code_349: -0.1008
# area_code_707: -0.0999
# domain_escortphonelist.com: -0.0972
# area_code_802: -0.0968
# area_code_623: -0.0877
# area_code_196: -0.0871
# ethnicity_arab: -0.0828
# area_code_667: -0.0821
# area_code_928: -0.0804
# domain_utopiaguide.com: -0.0774
# area_code_628: -0.0746
# area_code_190: -0.0701
# area_code_803: -0.0678
# incall_outcall_out: -0.0623
# age: -0.0584
# area_code_187: -0.0562
# area_code_583: -0.0507
# domain_usasexguide.com: -0.0502
# area_code_681: -0.0495
# area_code_495: -0.0480
# area_code_855: -0.0441
# area_code_12: -0.0419
# area_code_819: -0.0406
# area_code_620: -0.0397
# area_code_203: -0.0373
# area_code_11: -0.0322
# area_code_178: -0.0321
# area_code_386: 0.0308
# area_code_225: -0.0306
# area_code_234: 0.0300
# area_code_551: -0.0271
# area_code_361: 0.0270
# area_code_669: -0.0268
# area_code_442: 0.0218
# area_code_903: 0.0155
# area_code_573: -0.0146
# area_code_731: -0.0144
# area_code_774: -0.0129
# area_code_769: -0.0125
# domain_craigslist.com: -0.0102
# area_code_219: 0.0091
# latitude: 0.0090
# ethnicity_0: -0.0080
# area_code_779: 0.0066
# area_code_737: -0.0053
# domain_theeroticreview.com: -0.0040
# longitude: 0.0031
# domain_classivox.com: 0.0028
# area_code_605: 0.0023
# domain_vivastreet.com: -0.0010
# area_code_413: -0.0008
# area_code_657: -0.0004
# city_population_10K: 0.0001
# area_code_952: 0.0000
# area_code_936: 0.0000
# area_code_931: 0.0000
# area_code_902: 0.0000
# area_code_862: 0.0000
# area_code_18: 0.0000
# area_code_176: 0.0000
# area_code_639: 0.0000
# area_code_598: 0.0000
# area_code_594: 0.0000
# area_code_590: 0.0000
# area_code_10: 0.0000
# area_code_229: 0.0000
# area_code_195: 0.0000
# area_code_179: 0.0000
# area_code_660: 0.0000

# %%
from sklearn.metrics import confusion_matrix
y_pred = classifier.predict(X_test)
conf = confusion_matrix(y_test,y_pred,)
print(conf/np.sum(conf.flatten()))
print(conf)
# Out:
# [[ 0.48091004  0.03399582]
#  [ 0.03608787  0.44900628]]
# [[1839  130]
#  [ 138 1717]]

# %%
len(X_train)
# Out:
# 7762
