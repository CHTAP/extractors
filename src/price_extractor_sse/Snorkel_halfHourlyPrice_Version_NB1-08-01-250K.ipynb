# %% [markdown]
# # Step 1: Build the Dataset

# %% [markdown]
# The first thing to do is ensure that modules are auto-reloaded at runtime to allow for development in other files.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# We then set the Snorkel database location and start and connect to it.  By default, we use a PosgreSQL database backend, which can be created using `createdb DB_NAME` once psql is installed.  Note that Snorkel does *not* currently support parallel database processing with a SQLite backend.

# %%
# Setting Snorkel DB location
import os
import sys

import random
import numpy as np

#For networked PostgreSQL
postgres_location = 'postgresql://saeideh:123@localhost:5432'
postgres_db_name = 'sse_250K_price_test1'
os.environ['SNORKELDB'] = os.path.join(postgres_location,postgres_db_name)

#For local PostgreSQL
#os.environ['SNORKELDB'] = 'postgres:///es_locs_small'

# Adding path above for utils
sys.path.append('../utils')

# For SQLite
#db_location = '.'
#db_name = "es_locs_small.db"
#os.environ['SNORKELDB'] = '{0}:///{1}/{2}'.format("sqlite", db_location, db_name)

# Start Snorkel session
from snorkel import SnorkelSession
session = SnorkelSession()

# Setting random seed
seed = 1701
random.seed(seed)
np.random.seed(seed)

# %% [markdown]
# We now set the document preprocessor to read raw data into the Snorkel database.  There exist three possible data source options: JSONL files from the MEMEX project (option: `memex_jsons`), a raw tsv file of extractions from the memex project `content.tsv` (option: `content.tsv`), and tsvs with a similar format to `content.tsv` drawn from an Elasticsearch index of the data (option: `es`).  `max_docs` controls the number of documents read by the preprocessor, and `data_source` sets the location of the data.  For MEMEX json source, this should be a directory, while in all other cases it should be a tsv file.

# %%
# from dataset_utils import set_preprocessor, combine_dedupe

# # Set data source: options are 'content.tsv', 'memex_jsons', 'es'
# data_source = 'es'

# # Setting max number of docs to ingest
# max_docs = 1000

# # Setting location of data source

# # For ES:
# data_loc ="/dfs/scratch0/jdunnmon/data/memex-data/tsvs/price/output_all/output_all_shard_00.tsv"
# # Optional: add tsv with additional documents to create combined tsv without duplicates
# #data_all_loc = '/dfs/scratch1/jdunnmon/data/memex-data/es/output_all.tsv'
# #data_loc = combine_dedupe(data_loc, data_all_loc, '/dfs/scratch1/jdunnmon/data/memex-data/es/combined_phone_1M.tsv')

# # Setting preprocessor
# doc_preprocessor = set_preprocessor(data_source, data_loc, max_docs=max_docs, verbose=True,
#                                    clean_docs=True, content_field=['raw_content'])

# %% [markdown]
# Now, we execute the preprocessor.  Parallelism can be changed using the `parallelism` flag.  Note that we use the Spacy parser rather than CoreNLP, as this tends to give superior results.

# %%
from snorkel.parser import CorpusParser
from snorkel.parser.spacy_parser import Spacy

# Applying corpus parser
corpus_parser = CorpusParser(parser=Spacy())
# %time corpus_parser.apply(list(doc_preprocessor), parallelism=16, verbose=True)

# %% [markdown]
# Checking the number of parsed documents and sentences in the database.

# %%
from snorkel.models import Document, Sentence

# Printing number of docs/sentences
print("Documents:", session.query(Document).count())
print("Sentences:", session.query(Sentence).count())
# Out:
# Documents: 247439
# Sentences: 4891586

# %% [markdown]
# Separating into train, dev, and test sets

# %%
from dataset_utils import create_test_train_splits
from random import shuffle
docs = session.query(Document).order_by(Document.name).all()# load docs
#print (len(docs))
docs_sample = docs[:500]
#docs[0].sentences
shuffle(docs_sample)  # shuffle order

train_sents = set()
dev_sents = set()
test_sents = set()
numDocs = len(docs_sample)

splits = (0.9, 0.95) 
###
for i, doc in enumerate(docs_sample):
    #print (i)
    for s in doc.sentences:
      
        if i < splits[0] * numDocs:
            train_sents.add(s)
        elif i < splits[1] * numDocs:
            dev_sents.add(s)
        else:
            test_sents.add(s)

print('Training size: \t{},\
      \nDev size:     \t{},\
      \nTest size:    \t{}'.format(len(train_sents), len(dev_sents), len(test_sents)))
# # Getting all documents parsed by Snorkel
# docs = session.query(Document).order_by(Document.name).all()

# # Creating train, test, dev splits
# %time train_docs, dev_docs, test_docs, train_sents, dev_sents, test_sents = create_test_train_splits(docs, 'price', gold_dict=None, dev_frac=0.01, test_frac=0.01, hand_label=True)
# Out:
# Training size: 	8644,
# Dev size:     	660,
# Test size:    	488

# %% [markdown]
# Create candidate extractor.

# %% [markdown]
# ## Candidate Extractons and Filters

# %% [markdown]
# ### Defining Matchers

# %%
#price_regex = re.compile(r'[0-9]+[\.\,]?[0-9]*[:blank:]*\$')
# price_matcher_1= RegexMatchSpan(rgx =r'[0-9]+[\.\,]?[0-9]*[:blank:]*\$', longest_match_only = True)
# price_matcher_2= RegexMatchSpan(rgx =r'$\[0-9]+[\.\,]?[0-9]*[:blank:]', longest_match_only = True)
# price_matcher_3 = RegexMatchSpan(rgx =r'(\d+\.\d{1,2})')
# price_matcher_4 = RegexMatchSpan(rgx = r"[-+]?\d*\.\d+|\d+")#ur'([£$€])(\d+(?:\.\d{2})?)'
#price_matcher_5 = RegexMatchSpan(rgx = r'([£$€])(\d+(?:\.\d{2})?)')
####Define a relation's ContextSpaces


from snorkel.matchers import *
from snorkel.candidates import Ngrams, CandidateExtractor
import re
number_matcher = NumberMatcher(longest_match_only=True) 

#price_matcher= RegexMatchSpan(rgx =u'(\d+).(\d+)', longest_match_only = True)
price_matcher_1_=RegexMatchSpan(rgx = r"^\$+\d+(\d{1,2})?[.]\d{1,2}$")
price_matcher_2_=RegexMatchSpan(rgx = r"^\d+(\d{1,2})?[.]\d{1,2}$")
price_matcher_3_=RegexMatchSpan(rgx = r"^\$\d+(\d{1,2})?$")
price_matcher_4_=RegexMatchSpan(rgx = r"^\d+(\d{1,2})?$")

price_matcher = Union(price_matcher_1_, price_matcher_2_,price_matcher_3_,price_matcher_4_)#,price_matcher_5)
#price_ngrams = OmniNgrams(n_max=6, split_tokens=[])

# %% [markdown]
# ### Defining Filters

# %%
from snorkel.lf_helpers import (
    get_left_tokens, get_right_tokens, get_between_tokens,
    get_text_between, get_tagged_text)

def ngrams_halfhour_price_filter(cand):
    #lst = [,'hr','hour']
    price_terms =["hr","/hr","hour",'$hour,"hourly", "h", "$h","/hour']
    #time_term = [15]
    #$hh'
    half_terms = ["half", "hh",'$hh','hlf','hhr',"halfhour"]
    right_tokens =list(get_right_tokens(cand, window=2))
    left_tokens = list(get_left_tokens(cand, window=2))
    
    
    if cand[0].get_span()[-1] in ['5','0']:
        if len(list(set(half_terms) & set(right_tokens)))>0 or len(list(set(half_terms) & set(left_tokens)))>0:
            if len(list(set(price_terms) & set(right_tokens)))==0:
                if len(list(set(price_terms) & set(left_tokens)))==0:
                    return True
    
#     return False
# def ngrams_hourly_price_filter(cand):
#     #lst = [,'hr','hour']
#     price_terms =["hr","hour","/hr",'hour','$hour',"hourly",'h',"$h","/hour"]
#     #time_term = [15]
#     #$hh'
#     half_terms = ["half", "hh",'$hh','hlf','hhr',"halfhour"]
#     right_tokens =list(get_right_tokens(cand, window=2))
#     left_tokens = list(get_left_tokens(cand, window=2))
    
    
#     if cand[0].get_span()[-1] in ['5','0']:
#         if len(list(set(price_terms) & set(right_tokens)))>0 or len(list(set(price_terms) & set(left_tokens)))>0:
#             if len(list(set(half_terms) & set(right_tokens)))==0:
#                 if len(list(set(half_terms) & set(left_tokens)))==0:
#                     return True
    
#     return False
# def right_ngrams_price_filter(cand):
#     #lst = [,'hr','hour']
#     price_terms =["minutes","price","hr","hour","min","/hr","minutes$","mins",'hhr',
#             'roses', 'hlf', 'fh', 'hh',
#             'hour', '$hour', 'donation', '$hh', 'reg', 'qk', 'min$'
#             , 'prices', 'hourly', 'qh', '$h', 'nonnegotiable', 'half', 'varies', 'stays',"cash",'/hour',"diamonds"]

#     right_tokens =list(get_right_tokens(cand[0], window=4))
# #     if len(list(set(price_terms) & set(right_tokens)))>0:
# #         print (cand)
# #         #return cand
# #         return True
# #     else:
# #         return False
#     for c in right_tokens:
#         if c in price_terms:
#             return True
#         else:
#             return False
    
   
   
##if "half" not in cand_right_negrams:
#         for token in cand_right_negrams:
#             if token in lst:
#                 return cand
#     else:
#         return False
            
        
            
#candidate_filter= ngrams_hourly_price_filter
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e87eec261f96> in <module>()
#      68
#      69
# ---> 70 candidate_filter= ngrams_hourly_price_filter
#
# NameError: name 'ngrams_hourly_price_filter' is not defined

# %%
from snorkel.candidates import Ngrams
from snorkel.candidates import CandidateExtractor
from dataset_utils import create_candidate_class,CandidateExtractorFilter

# Setting extraction type -- should be a subfield in your data source extractions field!
extraction_type = 'price'

# Creating candidate class
candidate_class, candidate_class_name = create_candidate_class(extraction_type)

# Defining ngrams for candidates
ngrams = Ngrams(n_max=5)

# Uand matcher for candidate extractor
matcher = price_matcher
#cand_extractor = CandidateExtractor(candidate_class ,[ngrams],[matcher])#,candidate_filter=None)

# %%
cand_extractor = CandidateExtractorFilter(candidate_class ,[ngrams],[matcher])#,candidate_filter=candidate_filter)

# %% [markdown]
# Applying candidate extractor to each split (train, dev, test)

# %%
# Applying candidate extractor to each split
for k, sents in enumerate([train_sents, dev_sents, test_sents]):
    # %time cand_extractor.apply(sents, split=k, parallelism=1)
    print("Number of candidates:", session.query(candidate_class).filter(candidate_class.split == k).count())
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%
#
# CPU times: user 18.1 s, sys: 896 ms, total: 19 s
# Wall time: 24.9 s
# Number of candidates: 5314
# Clearing existing...
# Running UDF...
# [========================================] 100%
#
# CPU times: user 1.53 s, sys: 84 ms, total: 1.61 s
# Wall time: 1.9 s
# Number of candidates: 326
# Clearing existing...
# Running UDF...
# [========================================] 100%
#
# CPU times: user 1.44 s, sys: 84 ms, total: 1.53 s
# Wall time: 1.86 s
# Number of candidates: 302

# %% [markdown]
# ### candidate investigations

# %%
train_cand = session.query(candidate_class).filter(candidate_class.split == 0).all()

# %%
def ngrams_halfhour_price_filter(cand):
    #lst = [,'hr','hour']
    price_terms =["hr","/hr","hour",'$hour,"hourly", "h", "$h","/hour']
    #time_term = [15]
    #$hh'
    half_terms = ["half", "hh",'$hh','hlf','hhr',"halfhour"]
    right_tokens =list(get_right_tokens(cand, window=2))
    left_tokens = list(get_left_tokens(cand, window=2))
    
    
    if cand[0].get_span()[-1] in ['5','0']:
        if len(list(set(half_terms) & set(right_tokens)))>0 or len(list(set(half_terms) & set(left_tokens)))>0:
            if len(list(set(price_terms) & set(right_tokens)))==0:
                if len(list(set(price_terms) & set(left_tokens)))==0:
                    return True

# %%
train_cands = session.query(candidate_class).filter(candidate_class.split == 0).all()
print(len(train_cands))
train_dict = {}
for i, c in enumerate(train_cands):
    doc = c[0].sentence.document.name
    price = c[0].get_span().lower().split()
    text = c[0].get_parent().text.lower()
    #print (doc)
    r = ngrams_halfhour_price_filter(c)
    internal_dict = {}
    if r:
        
        #internal_dict["id"]= doc
        internal_dict["price/hour"]=price
        internal_dict["text"]= text
        train_dict[doc] = internal_dict


# for i, c in enumerate(train_cand):
#     name = c[0].get_span().lower().split()
#     name_1 = c[0].get_parent().text.lower()
#     print ("canidate:",name)
#     print(name_1)
# Out:
# 5314

# %%
print(len(list(train_dict.keys())))
train_dict
# Out:
# 22
# {"b'0075B4FC8D25FD95FFE5788F142BD9CD3BE10AFA1AFEA883D2BB6D179979F814'": {'price/hour': ['80'],
#   'text': 'url maryland backpage femaleescorts 5oqv b ty full bbw 80 hh e get drained 17551672.'},
#  "b'002162F17D43B54820A34F077974DBFD7211E7618510417A503310AD5260DD11'": {'price/hour': ['10'],
#   'text': '- michelles magic body rubs.$80 hh delight 10 am - 7 pm - 47'},
#  "b'005FDC2C41D375B514448469AA8D138D78727373E4A0CCBC8CB4C93F6220B5B6'": {'price/hour': ['60'],
#   'text': 'url washingtondc backpage bodyrubs special 40 hh 60 1hr forever wellness 21407858.'},
#  "b'0088E6A27F9FCC5DE8D1369B097589649A922CDE0E4665E1B96FDF5B11D50CEC'": {'price/hour': ['$80'],
#   'text': 'hi iam ready show you a good time iam available 24-7 my hh is $80 and my hr is $120 - 26'},
#  "b'0006C58C1E38399E623B2DA48B5C3AEA2346AA74EF557C98EECC33B402C35D62'": {'price/hour': ['$80'],
#   'text': 'hi iam ready show you a good time iam available 24-7 my hh is $80 and my hr is $120 - 26'},
#  "b'004FBFA990D5F28DC377CCB97FDC2BAD7082B41A4C4B851051D2BACC6865E1CD'": {'price/hour': ['100'],
#   'text': 'young~hot beautiful sexy japanese girl come 140 hr. 100 hhr - 22'},
#  "b'003953BCF27E389571836AD0E56D68F62DA13635C511A256B3620253F08D91E8'": {'price/hour': ['70'],
#   'text': '- georgiagirlspecial hh 70 - 28'},
#  "b'005A6B01E45B906871AEB2AE4990AF7E3D15C40C92C57598EBEB8217CF14F80F'": {'price/hour': ['50'],
#   'text': 'url fayettevillenc backpage therapeuticmassage private massage service certified 4 qualified masseuse hh 50 h 70 release donation free 31344410.'},
#  "b'00564CA28AB21FC1C03C31C7EC3BB687548225EE931544C093C32295D14687B0'": {'price/hour': ['60'],
#   'text': 'url toronto backpage ca femaleescorts scarborough 60 hh special 2 sweet asian asian girls c u m and warm up 1oo pics all menus 39762130.'},
#  "b'005EC5B4F74D9884B08E0CF9B9AA2C9ED794B448CE80B31C6FE7D252541CD2D5'": {'price/hour': ['$100'],
#   'text': 'donations are as follows $60 ss $100 hh 160 ls sorry no african-americans please excessive texting will not be tolerated 810 869-7229.call'},
#  "b'00860F6A617D5C82EB703D03DD123D45BDE7BC87D52A3A6ADD0CD96A26A9F7F6'": {'price/hour': ['110'],
#   'text': 'incall only 4124525067 110 hh 150 full hr no specials real deep tissue massage'},
#  "b'00504A2DE5B4E1588F6A1C8BBC39F2FABA412CF9AB8FA9DAD19DB08F889852D0'": {'price/hour': ['150'],
#   'text': '150 hh 75 qv special outcall specials now'},
#  "b'00339828699C65F59564C0FDF1785A27604F67D47F0A16586A816CA178CC9B9D'": {'price/hour': ['150'],
#   'text': 'hello, my name is rachelle and i am visiting mississauga for a few day. please call for details. i truly dislike texting. if you enjoy hanging out with a real doll that is smart, funny and oh so sexy then look no further. i love to experience all i can and share with you. i am 5 4, i weigh 115 lbs. tight smooth and oh so fit. < you must call to book an appointment with me.rachelle 1- 403- 629 - 0040 150 half hour200 hour 250 hour outcall.call'},
#  "b'004B7D9B76BEFACA07D17975D4CA81C98ABF9CD383E8315788B7A28D7A6D9584'": {'price/hour': ['100'],
#   'text': 'url denver backpage femaleescorts sexy and fun paris centennial 100 hhr special 29567332.'},
#  "b'005FB958D5FAFB35A474F62F717E2AD8F1DEC3137FD36C63B47A72664650332C'": {'price/hour': ['$80'],
#   'text': '$50 qv $80 hhr shayla thick n all da right places lets play - 25 for those men who deserve the best shayla 6784287034 spoil yourself a little. take a break from lifes stresses time with me & my amazing certified skills will leave you craving more i promise, youll love me upscale effortlessly beautiful no bs/no drama. incalls only no outs. qk 50 h/hr 80 hr 200'},
#  "b'007A7D35195C4E072BDAEF0B46BDFA474AD05C12A1355CEA7C5A88DC7042A7A3'": {'price/hour': ['$120'],
#   'text': 'hello gentlemen...are you looking for some safe, clean fun and a professional style massage? i am experienced with swedish, deep tissue and tantric style massage in my home...$80 for a half hour, $120 for an hour...519-917-3846...lauren'},
#  "b'004EAEB28EC937F266206AE56F540C07F828976154C5535ACEB22FA2A795A9ED'": {'price/hour': ['50'],
#   'text': 'come enjoy these soft amazing hands and this amazing deal it wont last long white men over 30 only clean and respectful no endless text please i host i dont do our call sorry my number is 7172889279 50 for half n 100 hour'},
#  "b'0041B8C7D61848C0A792278BBE200E2118AB0BECEECDB3EE7319879BF17C1C7A'": {'price/hour': ['120'],
#   'text': 'want to have an amazing time with a fun loving women. call or text sky 8042435140 satisfaction. incall available only right now 24/7 im available im waiting for you serious inquires only no pimps no cops please dnt waste my time n i wonlt waste urs if u cancle a apt u will not be allowed to reschedule 80 qv 120 hhr 150 hr by contacting me you agree to a written contract u agree you are not affiliated with any law enforcement agencies or cops'},
#  "b'006C6840C85B69FFE0B920F60178BE8EF071B7E650562074379A2972886A682B'": {'price/hour': ['120'],
#   'text': 'hey im in down town chilliwack i do out calls ca.r dat.es only unless u provide place. its 120 hh 200h contact me on 17788600079.call'},
#  "b'00362DD98FE87424A16797897B7E44D7CE2FB694F54C074B1EFBE86953FDEEEE'": {'price/hour': ['80'],
#   'text': 'respectable gentleman only i love fetishes no a.a sorry my donations are for my time only qv 80 hh 140 hour 200 346-715-4358 call me beauty .'},
#  "b'003FD3ADE9D6089F3E1834FC32C59C174D99286661E78D2B5D9046F003EE2029'": {'price/hour': ['80'],
#   'text': 'come have the time of your life with a easy going enjoyable cougar u cant go wrong with a lil experience can you well respected hygiene is a must at all times dont miss out on the time of ur life no aa qv 80 roses hhr 120 roses 180 roses nonnegotiable see u soon babe molly 904*386*9956. see my menu of services on my profile before calling...'},
#  "b'000C7E89BE2D2B11B09FF5EE4E99A44405878C5663BC756D569ED6FE72F5ABB1'": {'price/hour': ['150'],
#   'text': 'donations 100 qv, 150 hh or 200 fh'}}

# %%
dev_cands = session.query(candidate_class).filter(candidate_class.split == 1).all()
print(len(dev_cands))
dev_dict = {}
for i, c in enumerate(dev_cands):
    price = c[0].get_span().lower().split()
    text = c[0].get_parent().text.lower()
    #print (doc)
    r = ngrams_halfhour_price_filter(c)
    internal_dict = {}
    if r:
        
        internal_dict["id"]= doc
        internal_dict["price/hour"]=price
        internal_dict["text"]= text
        dev_dict[doc] = internal_dict
# Out:
# 326

# %%
print(len(list(dev_dict.keys())))
dev_dict
# Out:
# 1
# {"b'000933C0D6D4007511B1473E84CF086EF23CB1181AD09182572E8796A2749434'": {'id': "b'000933C0D6D4007511B1473E84CF086EF23CB1181AD09182572E8796A2749434'",
#   'price/hour': ['150'],
#   'text': 'slim, exotic, major hottie clean, outgoing, fun, sweet independent, professional hygiene is a must, must be clean be respectful when contacting me always text before you call no law enforcement no black men no pimps or thugs donation is for my time only 150 hhr 200 hr || do not negotiate || 615-810-0510.'}}

# %%
test_cands = session.query(candidate_class).filter(candidate_class.split == 2).all()
print(len(test_cands))
test_dict = {}
for i, c in enumerate(test_cands):
    
    price = c[0].get_span().lower().split()
    print(price)
    text = c[0].get_parent().text.lower()
    print(text)
    #print (doc)
    r = ngrams_halfhour_price_filter(c)
    internal_dict = {}
    if r:
        
        internal_dict["id"]= doc
        internal_dict["price/hour"]=price
        internal_dict["text"]= text
        test_dict[doc] = internal_dict
# Out:
# 302
# ['35']
# man gets 35 years for impersonating cop to get free sex from hooker
# ['2017']
# tacoma.backpage.com is an interactive computer service that enables access by multiple users and should not be treated as the publisher or speaker of any information provided by another information content provider. 2017
# ['7541168']
# title 423-888-8141 chattanooga tennessee escort 7541168
# ['30']
# college park, maryland prostitution sting: 30 arrested
# ['160']
# hello gentleman. my name is natalie. im a 25 year old young lady. i have an exotic lineage with my mother being half korean and half black and my father hailing from the dominican republic.im interested in meeting respectful generous gentlemen who just want to kickback and spend some quality time with a beautiful young woman. *always clean. *always well dressed. *57 160 lbs with all natural 36f breasts.. really. natalie 786-592-4019 *explicit talk ends call.**. see my menu of services on my profile before calling...
# ['25']
# hello gentleman. my name is natalie. im a 25 year old young lady. i have an exotic lineage with my mother being half korean and half black and my father hailing from the dominican republic.im interested in meeting respectful generous gentlemen who just want to kickback and spend some quality time with a beautiful young woman. *always clean. *always well dressed. *57 160 lbs with all natural 36f breasts.. really. natalie 786-592-4019 *explicit talk ends call.**. see my menu of services on my profile before calling...
# ['1']
# study: 1 in 6 sex offenders live double life
# ['6']
# study: 1 in 6 sex offenders live double life
# ['253']
# url taa backpage therapeuticmassage grand open table shower free new young petty chinese girl 253 539 5644 30106168.
# ['5644']
# url taa backpage therapeuticmassage grand open table shower free new young petty chinese girl 253 539 5644 30106168.
# ['539']
# url taa backpage therapeuticmassage grand open table shower free new young petty chinese girl 253 539 5644 30106168.
# ['0782']
# url www eroticmugshots virginiabeach escorts 757 802 0782 ?pid=20915783.
# ['802']
# url www eroticmugshots virginiabeach escorts 757 802 0782 ?pid=20915783.
# ['757']
# url www eroticmugshots virginiabeach escorts 757 802 0782 ?pid=20915783.
# ['13965650']
# url 786 592 4019 escortphonelist super hot super busty asian mixx avail now 13965650 html.
# ['4019']
# url 786 592 4019 escortphonelist super hot super busty asian mixx avail now 13965650 html.
# ['786']
# url 786 592 4019 escortphonelist super hot super busty asian mixx avail now 13965650 html.
# ['592']
# url 786 592 4019 escortphonelist super hot super busty asian mixx avail now 13965650 html.
# ['80']
# papi.i am the real deal. i know your tired of off brand b*. $o come deal with a real chick. i am deff waiting for u. i got what u need papi. great and unrushed services. @ll th@t @$. thick in the right places and tightly petite the rest... sexy body 50 qv. 80 hhr. 1oo 4 2 busts. 150 hr. 2oo 4 3 busts. 100% real pics.all is me papi. just eait till u see. ill make your heart melt.202 883 0228amporia love. i offer video/photo also, ask me on my profile before calling...
# ['883']
# papi.i am the real deal. i know your tired of off brand b*. $o come deal with a real chick. i am deff waiting for u. i got what u need papi. great and unrushed services. @ll th@t @$. thick in the right places and tightly petite the rest... sexy body 50 qv. 80 hhr. 1oo 4 2 busts. 150 hr. 2oo 4 3 busts. 100% real pics.all is me papi. just eait till u see. ill make your heart melt.202 883 0228amporia love. i offer video/photo also, ask me on my profile before calling...
# ['4']
# papi.i am the real deal. i know your tired of off brand b*. $o come deal with a real chick. i am deff waiting for u. i got what u need papi. great and unrushed services. @ll th@t @$. thick in the right places and tightly petite the rest... sexy body 50 qv. 80 hhr. 1oo 4 2 busts. 150 hr. 2oo 4 3 busts. 100% real pics.all is me papi. just eait till u see. ill make your heart melt.202 883 0228amporia love. i offer video/photo also, ask me on my profile before calling...
# ['3']
# papi.i am the real deal. i know your tired of off brand b*. $o come deal with a real chick. i am deff waiting for u. i got what u need papi. great and unrushed services. @ll th@t @$. thick in the right places and tightly petite the rest... sexy body 50 qv. 80 hhr. 1oo 4 2 busts. 150 hr. 2oo 4 3 busts. 100% real pics.all is me papi. just eait till u see. ill make your heart melt.202 883 0228amporia love. i offer video/photo also, ask me on my profile before calling...
# ['150']
# papi.i am the real deal. i know your tired of off brand b*. $o come deal with a real chick. i am deff waiting for u. i got what u need papi. great and unrushed services. @ll th@t @$. thick in the right places and tightly petite the rest... sexy body 50 qv. 80 hhr. 1oo 4 2 busts. 150 hr. 2oo 4 3 busts. 100% real pics.all is me papi. just eait till u see. ill make your heart melt.202 883 0228amporia love. i offer video/photo also, ask me on my profile before calling...
# ['50']
# papi.i am the real deal. i know your tired of off brand b*. $o come deal with a real chick. i am deff waiting for u. i got what u need papi. great and unrushed services. @ll th@t @$. thick in the right places and tightly petite the rest... sexy body 50 qv. 80 hhr. 1oo 4 2 busts. 150 hr. 2oo 4 3 busts. 100% real pics.all is me papi. just eait till u see. ill make your heart melt.202 883 0228amporia love. i offer video/photo also, ask me on my profile before calling...
# ['4']
# papi.i am the real deal. i know your tired of off brand b*. $o come deal with a real chick. i am deff waiting for u. i got what u need papi. great and unrushed services. @ll th@t @$. thick in the right places and tightly petite the rest... sexy body 50 qv. 80 hhr. 1oo 4 2 busts. 150 hr. 2oo 4 3 busts. 100% real pics.all is me papi. just eait till u see. ill make your heart melt.202 883 0228amporia love. i offer video/photo also, ask me on my profile before calling...
# ['2']
# papi.i am the real deal. i know your tired of off brand b*. $o come deal with a real chick. i am deff waiting for u. i got what u need papi. great and unrushed services. @ll th@t @$. thick in the right places and tightly petite the rest... sexy body 50 qv. 80 hhr. 1oo 4 2 busts. 150 hr. 2oo 4 3 busts. 100% real pics.all is me papi. just eait till u see. ill make your heart melt.202 883 0228amporia love. i offer video/photo also, ask me on my profile before calling...
# ['360']
# naughtyreviews offers a unique dating experience that allows you to have the perfect date every time. thanks to our revolutionary 360 degree ratings system guys and girls can rate each other to keep things safe and predictable. start to rate and get rated today to increase your member level and gain access to the most exclusive dating opportunities. naughtyreviews makes it easy to find the hottest girls, and provides a platform so that you can incentivize them to go out with you. girls and guys want to go out with people they know are safe and reliable. naughtyreviews makes that possible through safety levels which are based upon a peer review system.
# ['0220']
# url 202 883 0220 escortphonelist th3 r3 l d3 l l t n bombshell 50 specialz 14027949 html.
# ['14027949']
# url 202 883 0220 escortphonelist th3 r3 l d3 l l t n bombshell 50 specialz 14027949 html.
# ['50']
# url 202 883 0220 escortphonelist th3 r3 l d3 l l t n bombshell 50 specialz 14027949 html.
# ['202']
# url 202 883 0220 escortphonelist th3 r3 l d3 l l t n bombshell 50 specialz 14027949 html.
# ['883']
# url 202 883 0220 escortphonelist th3 r3 l d3 l l t n bombshell 50 specialz 14027949 html.
# ['1']
# study: 1 in 6 sex offenders live double life
# ['6']
# study: 1 in 6 sex offenders live double life
# ['29']
# title 757-802-0782 escort alert! - bbw kissing is my favorite - 29
# ['330']
# url www eroticmugshots akron escorts 330 734 9971 ?pid=33982506.
# ['9971']
# url www eroticmugshots akron escorts 330 734 9971 ?pid=33982506.
# ['734']
# url www eroticmugshots akron escorts 330 734 9971 ?pid=33982506.
# ['21']
# title __ _ _ _ _ __ __ massage ladies wanted asap _ _ __ __ immediate massage work is available - 21 - a sexy service com
# ['7578020782']
# please read entire ad highly reviewed, high quality, low volume, sexy, sensual bbw looking for a gentleman to spend time with. i love kissing. no men under 30. no aa. insulting offers will be blocked. appointment only at least one hour prior to meeting. text taylor 7578020782 .call
# ['21']
# __ _ _ _ _ __ __ massage ladies wanted asap _ _ __ __ immediate massage work is available - 21
# ['29']
# sexy bbw that loves to kiss - 29
# ['29']
# rated one of the best in areasexy bbw that loves to kiss - 29
# ['29']
# highly reviewed bbw that loves to kiss - 29
# ['29']
# kissing is a must. passionate brunette bbw - 29
# ['34160']
# url utopiaguide forums threads stds 34160 .
# ['28']
# your new addiction i love to kiss. - 28
# ['21']
# must be at least 21 years of age with valid i.d. and have previous experience.
# ['28']
# one of a kind sexy brunette bbw i love kissing - 28
# ['28']
# kissing is my favorite. sexy bbw - 28
# ['28']
# sexy and sultry brunette bbw awesome reviews - 28
# ['28']
# sexy sultry bbw that loves kissing - 28
# ['21']
# you will me. gorgeously sexy latin - 21
# ['21']
# wow. must take a look at this. - 21
# ['21']
# here to please all your desirescall me 100% real curvy white girl. - 21
# ['250']
# var ad_idzone = 2166943,ad_width = 250,ad_height = 250
# ['21']
# beautiful salvadorean the one and only(: - 21
# ['21']
# new girl persian gem exotic blend - 21
# ['250']
# var ad_idzone = 2167017,ad_width = 250,ad_height = 250
# ['21']
# young & tight taste like come play with me - 21
# ['18']
# new to town dont miss me 100$ specials - 18
# ['40']
# looking for a girl that can do this - 40
# ['19']
# super specials red bone thick incalls - 19
# ['25']
# doing out calls and im calls - 25
# ['9971']
# doing in calls and out calls 330- 734- 9971 - 25
# ['25']
# doing in calls and out calls 330- 734- 9971 - 25
# ['22']
# - sexy beauty desiree 1000% real - 22
# ['9971']
# doing in calls and out calls 330- 734- 9971 - 25
# ['25']
# doing in calls and out calls 330- 734- 9971 - 25
# ['22']
# - a l l o f t h e a b o v e - 22
# ['23']
# doin outcalls 330- 734- 9971 - 23
# ['9971']
# doin outcalls 330- 734- 9971 - 23
# ['22']
# - n.e.w vanessa mind skills truly a mans best friend the real trophy - 22
# ['9971']
# doing in calls 330- 734- 9971 - 25
# ['25']
# doing in calls 330- 734- 9971 - 25
# ['20']
# - new mixed caramel beauty bo0bies & bo0ty $80 hh available now. - 20
# ['$80']
# - new mixed caramel beauty bo0bies & bo0ty $80 hh available now. - 20
# ['25']
# in calls only for grown sexy serious men - 25
# ['21']
# - 60sexy freak vbe 24/7come let me bounce this ass & - 21
# ['25']
# in calls and out calls for grown serious men - 25
# ['20']
# - earlybird now. [azzzzzzz clapping fun] new pics[curvy big booty] % real call - 20
# ['21']
# you will me. gorgeously sexy latin - 21
# ['20']
# - n os euctive & aictive psc playmateh r d - 20
# ['21']
# wow. must take a look at this. - 21
# ['20']
# - 60 special. available now. early bird specials [after work specials]sexy fac - 20
# ['60']
# - 60 special. available now. early bird specials [after work specials]sexy fac - 20
# ['21']
# here to please all your desirescall me 100% real curvy white girl. - 21
# ['20']
# - --- erotic dancer curvy silhouette --- top of the line services let mefufill - 20
# ['21']
# beautiful salvadorean the one and only(: - 21
# ['20']
# - super sexy and soo worth it stop wasting time w/ the rest, call the best. - 20
# ['21']
# new girl persian gem exotic blend - 21
# ['20']
# - newcertified freakcurves petiteg bies trophy - 20
# ['20']
# - diamond red bone gives messy climaxincalls - 20
# ['18']
# new to town dont miss me 100$ specials - 18
# ['20']
# - the p treat you havent hadthe best until youve hadme - 20
# ['20']
# - upsc ebony jw dropping ptit & sweet gir nxt door - 20
# ['19']
# super specials red bone thick incalls - 19
# ['20']
# - independence exotic & erotic, % real goddess, do not miss out fellas. - 20
# ['20']
# - incallstight ..juicy lips gorgeous face discreet & shower fresh wb - 20
# ['20']
# - w. broad sxy* y0ung butiful & nughty ready now - 20
# ['20']
# - kalii bangin %upscale provider))norush i give what you desire - 20
# ['20']
# - kalii bangin %upscale provider))norush i give what you desire - 20
# ['35']
# man gets 35 years for impersonating cop to get free sex from hooker
# ['20']
# - kalii bangin %upscale provider))norush i give what you desire - 20
# ['5712518']
# title amanda4u2@hotmail com amandaella miami florida escort 5712518
# ['20']
# - kalii bangin %upscale provider))norush i give what you desire - 20
# ['5712518']
# on friday, december 30th, 2016 in miami escorts postid 5712518
# ['2016']
# on friday, december 30th, 2016 in miami escorts postid 5712518
# ['20']
# - west broad kalii bangin %upscale provider))norush i give what you desire - 20
# ['30']
# college park, maryland prostitution sting: 30 arrested
# ['20']
# - qvincall sp freaky & cute & slim hot ebony gem - 20
# ['99.9']
# hey there handsome let me take you away from all that day to day stress with a hhr to an hhr long sensual body rub? all you gotta do is pick up the phone and dial 2702825314 and you are on your way to ecstasy. my percentage is 99.9 % satisfaction. i am clean discreet 100% independent and ready to please you. call soon for an appointment...2702825314 im waiting.no cheap donations please
# ['2702825314']
# hey there handsome let me take you away from all that day to day stress with a hhr to an hhr long sensual body rub? all you gotta do is pick up the phone and dial 2702825314 and you are on your way to ecstasy. my percentage is 99.9 % satisfaction. i am clean discreet 100% independent and ready to please you. call soon for an appointment...2702825314 im waiting.no cheap donations please
# ['22']
# search location bowling green, exit 22
# ['2017']
# kentucky.backpage.com is an interactive computer service that enables access by multiple users and should not be treated as the publisher or speaker of any information provided by another information content provider. 2017
# ['60']
# title 60 short stay pick one r both 2girls - houston escorts - backpage com
# ['19']
# 60 short stay pick one r both 2girls - 19
# ['60']
# 60 short stay pick one r both 2girls - 19
# ['2']
# r ask for shay 832-721-2660 s xy* 2 y0ung b utiful & n ughty girls ready now ask about our two girls r pick u one. are you wanting to try something new give us a call im very professional,upscale,very discreet and your secrets are safe with me im looking to enjoy my self with bussiness men no cheap men im available all night so give me a call! a nice safe place thick women do it better accept gifts & tips on paypal
# ['2017']
# houston.backpage.com is an interactive computer service that enables access by multiple users and should not be treated as the publisher or speaker of any information provided by another information content provider. 2017
# ['60']
# url houston backpage femaleescorts 60 short stay pick one r both 2girls 38911682.
# ['29']
# title 757-802-0782 escort alert! - bbw kissing is my favorite - 29
# ['24']
# hey guys im naya im a student and a part time model. im visiting from california im the perfect girl i love to party and meet new people. im staying near northwest hwy, but will travel call me now.. i stay up late. im 24 years old with an hourglass shape
# ['25']
# title 330-734-9971 - escort ad - doing out calls and over night stays - 25
# ['25']
# title 330-734-9971 - escort ad - doing out calls and over night stays - 25
# ['2017']
# dallas.backpage.com is an interactive computer service that enables access by multiple users and should not be treated as the publisher or speaker of any information provided by another information content provider. 2017
# ['21']
# you will me. gorgeously sexy latin - 21
# ['21']
# wow. must take a look at this. - 21
# ['21']
# here to please all your desirescall me 100% real curvy white girl. - 21
# ['21']
# beautiful salvadorean the one and only(: - 21
# ['360']
# naughtyreviews offers a unique dating experience that allows you to have the perfect date every time. thanks to our revolutionary 360 degree ratings system guys and girls can rate each other to keep things safe and predictable. start to rate and get rated today to increase your member level and gain access to the most exclusive dating opportunities. naughtyreviews makes it easy to find the hottest girls, and provides a platform so that you can incentivize them to go out with you. girls and guys want to go out with people they know are safe and reliable. naughtyreviews makes that possible through safety levels which are based upon a peer review system.
# ['21']
# new girl persian gem exotic blend - 21
# ['25']
# doing out calls and over night stays - 25
# ['25']
# doing out calls and in calls - 25
# ['18']
# new to town dont miss me 100$ specials - 18
# ['25']
# doing in calls and out calls and over night stays - 25
# ['27']
# doing out calls and in calls - 27
# ['19']
# super specials red bone thick incalls - 19
# ['9971']
# doing in calls 330- 734- 9971 co - 25
# ['25']
# doing in calls 330- 734- 9971 co - 25
# ['25']
# doing in calls 330- 734- 9971 - 25
# ['9971']
# doing in calls 330- 734- 9971 - 25
# ['360']
# naughtyreviews offers a unique dating experience that allows you to have the perfect date every time. thanks to our revolutionary 360 degree ratings system guys and girls can rate each other to keep things safe and predictable. start to rate and get rated today to increase your member level and gain access to the most exclusive dating opportunities. naughtyreviews makes it easy to find the hottest girls, and provides a platform so that you can incentivize them to go out with you. girls and guys want to go out with people they know are safe and reliable. naughtyreviews makes that possible through safety levels which are based upon a peer review system.
# ['27']
# doing out calls 330- 734- 9971 and in calls - 27
# ['9971']
# doing out calls 330- 734- 9971 and in calls - 27
# ['27']
# doing out calls and in calls - 27
# ['25']
# doing out calls and im calls - 25
# ['35']
# man gets 35 years for impersonating cop to get free sex from hooker
# ['25']
# doing out calls and in calls - 25
# ['25']
# doing out calls and in calls - 25
# ['9971']
# doing in calls im ready 330- 734- 9971 and out calls - 27
# ['27']
# doing in calls im ready 330- 734- 9971 and out calls - 27
# ['30']
# college park, maryland prostitution sting: 30 arrested
# ['25']
# doing in calls im ready 330- 734- 9971 and out calls - 25
# ['9971']
# doing in calls im ready 330- 734- 9971 and out calls - 25
# ['1']
# study: 1 in 6 sex offenders live double life
# ['6']
# study: 1 in 6 sex offenders live double life
# ['25']
# doing in calls and out calls - 25
# ['9971']
# doing in calls im ready 330- 734- 9971 - 25
# ['25']
# doing in calls im ready 330- 734- 9971 - 25
# ['50']
# found 50 posts for phone number
# ['25']
# doing in calls and out calls - 25
# ['593']
# url www eroticmugshots sandiego escorts 420 593 8293 ?pid=20689197.
# ['420']
# url www eroticmugshots sandiego escorts 420 593 8293 ?pid=20689197.
# ['8293']
# url www eroticmugshots sandiego escorts 420 593 8293 ?pid=20689197.
# ['25']
# doing in calls 330- 734- 9971 and out calls - 25
# ['9971']
# doing in calls 330- 734- 9971 and out calls - 25
# ['69']
# your #1 source for adult entertainment for lake george & saratoga! no deposit! call 518-885-0290 - 69
# ['20']
# - bootybeauty on duty available now sweet freaky treat - 20
# ['69']
# your #1 source for party strippers in saratoga, albany & beyond!!!! no deposit or cc needed! - 69
# ['250']
# var ad_idzone = 2166943,ad_width = 250,ad_height = 250
# ['20']
# - sxy* y0ung butiful & nughty ready now - 20
# ['250']
# var ad_idzone = 2166983,ad_width = 250,ad_height = 250
# ['20']
# - sxy* y0ung butiful & nughty ready now - 20
# ['50']
# mature sexy naturally busty curvy blue eyed european bonde escort massage fetishes toys - 50
# ['21']
# new york hardbodies strippers home for the wildest full nude bachelor parties call us 518-306-7090 - 21
# ['20']
# - pumpkin spice ( very nice .stop by ,taste my pumpkin pie. - 20
# ['50']
# mature naturally busty 40dd curvy blue eyed european blonde independent escort massage fetishes toys - 50
# ['21']
# start asap all clients pre-screened * guaranteed appts * stack cash for the holidays! - 21
# ['22']
# - % r e a l uivevnillt 5service # playmate - 22
# ['50']
# mature naturally busty 40dd curvy blue eyed european blonde independent escort massage fetishes toys - 50
# ['250']
# var ad_idzone = 2167013,ad_width = 250,ad_height = 250
# ['21']
# - exquisite beauty comeover - 21
# ['50']
# mature sexy naturally busty curvy blue eyed european bonde escort massage fetishes toys - 50
# ['250']
# var ad_idzone = 2167017,ad_width = 250,ad_height = 250
# ['21']
# - exquisite beauty come indulge in pure satisfaction - 21
# ['50']
# mature naturally busty 40dd curvy blue eyed european blonde independent escort massage fetishes toys - 50
# ['21']
# new york hardbodies strippers home for the wildest full nude bachelor parties call us - 21
# ['21']
# new ebony mixed tall babe outcalls special - 21
# ['20']
# - kalii bangin %upscale provider))norush i give what you desire - 20
# ['2017']
# toronto.backpage.ca is an interactive computer service that enables access by multiple users and should not be treated as the publisher or speaker of any information provided by another information content provider. 2017
# ['20']
# - perky bubbly new 100% real white chick t.@ht body specialssweet & beauti - 20
# ['40']
# url toronto backpage ca bodyrubs mature european blonde naturally busty 40 dd curvy thick voluptuous escort massage fetishes toys 32568608.
# ['23']
# #1 free strip club review site - 23
# ['30']
# now hiring *tired of that dead end job -seeking for a better outlet to achieve those goals - 30
# ['20']
# - super sexy and soo worth it stop wasting time w/ the rest, call the best. - 20
# ['2']
# it is a tough job inspecting everyones mouths for signs of infection and disease but it must be done ...therefore this is why when i personally meet a new friend for the first time ..... i suggest at least a 2 hr meeting to give me time to acess the persons body parts which will be touching any of mine .
# ['20']
# - kalii bangin %upscale provider))norush i give what you desire - 20
# ['969']
# upstate lesbian strippers 1 866 969 5960 delivered 2 u! - 18
# ['2']
# upstate lesbian strippers 1 866 969 5960 delivered 2 u! - 18
# ['5960']
# upstate lesbian strippers 1 866 969 5960 delivered 2 u! - 18
# ['1']
# upstate lesbian strippers 1 866 969 5960 delivered 2 u! - 18
# ['18']
# upstate lesbian strippers 1 866 969 5960 delivered 2 u! - 18
# ['866']
# upstate lesbian strippers 1 866 969 5960 delivered 2 u! - 18
# ['45']
# established porn studio needs straight males for scenes & videos - 45
# ['20']
# - new funsized ebony bombshell super freaky open minded & kinky the best new - 20
# ['5960']
# 1 866 969 5960 hott lesbian strippers delivered 2 your upstate...
# ['2']
# 1 866 969 5960 hott lesbian strippers delivered 2 your upstate...
# ['1']
# 1 866 969 5960 hott lesbian strippers delivered 2 your upstate...
# ['866']
# 1 866 969 5960 hott lesbian strippers delivered 2 your upstate...
# ['969']
# 1 866 969 5960 hott lesbian strippers delivered 2 your upstate...
# ['20']
# - ebony bombshell model can u handle me ur personal porn - 20
# ['$245']
# $245 no time limit female & male strippers 800-788-1785 - 21
# ['21']
# $245 no time limit female & male strippers 800-788-1785 - 21
# ['250']
# var ad_idzone = 2167013,ad_width = 250,ad_height = 250
# ['250']
# var ad_idzone = 2166993,ad_width = 250,ad_height = 250
# ['20']
# cute petite cocoa complected goddess - 20
# ['40']
# title mature european blonde --naturally busty 40 dd curvy thick voluptuous escort massage fetishes toys - toronto body rubs - backpage ca
# ['50']
# mature european blonde --naturally busty 40 dd curvy thick voluptuous escort massage fetishes toys - 50
# ['40']
# mature european blonde --naturally busty 40 dd curvy thick voluptuous escort massage fetishes toys - 50
# ['35']
# gia donnas secrets !! escort referral service seeking companions now !! - 35
# ['2017']
# posted: thursday, january 5, 2017 12:11 pm
# ['18']
# xclusive entertainment-_-now hiring dancers and private escorts-_- #1 since 2007-get paid tonight- - 18
# ['25']
# sophia si able espanol hable mi orita papi - 25
# ['$300']
# outcall to your hotel downtown, airport: $300
# ['757']
# url www escortsinthe us 757 698 1814 .
# ['1814']
# url www escortsinthe us 757 698 1814 .
# ['698']
# url www escortsinthe us 757 698 1814 .
# ['427']
# hosting at 427 & evans, browns line, near sherway gardens just off the qew.
# ['100']
# ///// if you wish to be inspired. motivated. educated . there is only one place to be. _______ posh - 100
# ['250']
# var ad_idzone = 2166993,ad_width = 250,ad_height = 250
# ['90']
# escape the cold with a warm, fullbody 90 minute erotic, sensual massage (women only) - 42
# ['42']
# escape the cold with a warm, fullbody 90 minute erotic, sensual massage (women only) - 42
# ['250']
# var ad_idzone = 2167013,ad_width = 250,ad_height = 250
# ['36']
# ladies come get 100% down for my ddys crown? loyalty b4 royalty - 36
# ['21']
# title new york hardbodies strippers home for the wildest full nude bachelor parties call us - 21 - a sexy service com
# ['21']
# female owned body rub will train $1000/day *easy money** - 21
# ['21']
# new york hardbodies strippers home for the wildest full nude bachelor parties call us - 21
# ['$800']
# were hiring ladies now 4 the new year! can u travel?? paid daily txt me! $800 day #success
# ['4']
# were hiring ladies now 4 the new year! can u travel?? paid daily txt me! $800 day #success
# ['252']
# title pro motion now $ 50/50 min four hand special asian spa 252 bradford st - barrie body rubs - backpage ca
# ['50']
# title pro motion now $ 50/50 min four hand special asian spa 252 bradford st - barrie body rubs - backpage ca
# ['23']
# pro motion now $ 50/50 min four hand special asian spa 252 bradford st - 23
# ['252']
# pro motion now $ 50/50 min four hand special asian spa 252 bradford st - 23
# ['50']
# pro motion now $ 50/50 min four hand special asian spa 252 bradford st - 23
# ['250']
# var ad_idzone = 2166993,ad_width = 250,ad_height = 250
# ['2017']
# posted: wednesday, january 4, 2017 1:23 am
# ['2']
# home for the wildest full nude bachelor parties call us today to reserve this special rate for the weekend before were sold out $500/2 girls including girl on girl show
# ['6']
# search location barrie, ontario take hwy 400, exit 94, go past 6 traffic lights, and it will be on the northwest of bradford street and tiffen street
# ['252']
# search location 252 bradford st barrie, barrie
# ['$1000']
# *were always hiring new talent u could make up to $1000 per weekend just for having fun and partying
# ['252']
# hot & beautiful asian girls $30/30 min 252 bradford st - 21
# ['30']
# hot & beautiful asian girls $30/30 min 252 bradford st - 21
# ['21']
# hot & beautiful asian girls $30/30 min 252 bradford st - 21
# ['22']
# barrie best massage 30 /30m252 bradford st hot hot hot - 22
# ['30']
# barrie best massage 30 /30m252 bradford st hot hot hot - 22
# ['23']
# barrie best nuru massage @252 bradford st hot hot hot - 23
# ['250']
# var ad_idzone = 2166943,ad_width = 250,ad_height = 250
# ['24']
# barrie best nuru massage @252 bradford st $30/30min - 24
# ['22']
# $30/30 m barrie best massage @252 bradford st hot hot hot - 22
# ['30']
# $30/30 m barrie best massage @252 bradford st hot hot hot - 22
# ['20']
# hottest strippers for your party. wild party games 800-695-6349!!! - 20
# ['2017']
# barrie.backpage.ca is an interactive computer service that enables access by multiple users and should not be treated as the publisher or speaker of any information provided by another information content provider. 2017
# ['50']
# url barrie backpage ca bodyrubs pro motion now 50 50 min four hand special asian spa 252 bradford st 24376810.
# ['252']
# url barrie backpage ca bodyrubs pro motion now 50 50 min four hand special asian spa 252 bradford st 24376810.
# ['50']
# url barrie backpage ca bodyrubs pro motion now 50 50 min four hand special asian spa 252 bradford st 24376810.
# ['2017']
# posted: tuesday, january 10, 2017 3:01 pm
# ['250']
# var ad_idzone = 2167017,ad_width = 250,ad_height = 250
# ['5']
# 5 feet 4 inches - 5 feet 7 inches
# ['7']
# 5 feet 4 inches - 5 feet 7 inches
# ['5']
# 5 feet 4 inches - 5 feet 7 inches
# ['4']
# 5 feet 4 inches - 5 feet 7 inches
# ['21']
# wild party strippers 518-306-7090 - 21
# ['5']
# promotion grand opening discount any price $ 5 off
# ['72118385']
# post id: 72118385 sanfernandovalley
# ['2017']
# sanfernandovalley.backpage.com is an interactive computer service that enables access by multiple users and should not be treated as the publisher or speaker of any information provided by another information content provider. 2017
# ['25']
# lets celebrate the new year with a bigbang - 25
# ['4']
# hi my name is arianna and i would like to say that im very sweet, feminine, educated with soft olive skin and i can always make this experience a memorable one for you. my statistic is 54 110lbs with 34d breast. im very hygienic thus im expecting that from you when we meet. the money you give is solely for the time being spent with me. i dont post a lot of pictures because im a college student. i do incall & outcall u can text or call me 3108715422 facetime/skype 4 verification
# ['54']
# hi my name is arianna and i would like to say that im very sweet, feminine, educated with soft olive skin and i can always make this experience a memorable one for you. my statistic is 54 110lbs with 34d breast. im very hygienic thus im expecting that from you when we meet. the money you give is solely for the time being spent with me. i dont post a lot of pictures because im a college student. i do incall & outcall u can text or call me 3108715422 facetime/skype 4 verification
# ['3108715422']
# hi my name is arianna and i would like to say that im very sweet, feminine, educated with soft olive skin and i can always make this experience a memorable one for you. my statistic is 54 110lbs with 34d breast. im very hygienic thus im expecting that from you when we meet. the money you give is solely for the time being spent with me. i dont post a lot of pictures because im a college student. i do incall & outcall u can text or call me 3108715422 facetime/skype 4 verification
# ['30']
# title now hiring *tired of that dead end job -seeking for a better outlet to achieve those goals - 30 - a sexy service com
# ['2017']
# sanjose.backpage.com is an interactive computer service that enables access by multiple users and should not be treated as the publisher or speaker of any information provided by another information content provider. 2017
# ['2017']
# posted: wednesday, january 11, 2017 2:19 pm
# ['30']
# now hiring *tired of that dead end job -seeking for a better outlet to achieve those goals - 30
# ['2']
# feeling sore and overworked? want to be pampered? let me take care of you! call or text 717-953-6070 i do massages in my home 60$ per 1/2 hour! hope to see you soon!
# ['30']
# we are exclusive women own socialite companionship agency seeking for few selective attractive model type women between the ages of 18 and 30 with extremely outgoing personalities. we cater to only (well screened) professional clientele who know how to treat a lady and has generous compensation habits.what we offer you:
# ['18']
# we are exclusive women own socialite companionship agency seeking for few selective attractive model type women between the ages of 18 and 30 with extremely outgoing personalities. we cater to only (well screened) professional clientele who know how to treat a lady and has generous compensation habits.what we offer you:
# ['15']
# search location harrisburg, near liverpool off 11/15
# ['1']
# 1 hour and table shower: $60/60mins
# ['42']
# title 420-593-8293 just arrived in sd seeking a generous gentleman - 42
# ['2017']
# harrisburg.backpage.com is an interactive computer service that enables access by multiple users and should not be treated as the publisher or speaker of any information provided by another information content provider. 2017
# ['42']
# title 420-593-8293 just arrived in sd seeking a generous gentleman - 42
# ['30']
# attractive model type female age 18-30 years old
# ['253']
# call for appointment at 253 539 5644
# ['539']
# call for appointment at 253 539 5644
# ['5644']
# call for appointment at 253 539 5644
# ['98444']
# 321 138th st s # b4, tacoma wa 98444
# ['321']
# 321 138th st s # b4, tacoma wa 98444
# ['24']
# hot busty california party girl available now!!! - 24
# ['2017']
# posted: saturday, january 14, 2017 8:17 pm
# ['2']
# grand open sweet girls free table shower ! 2 girls 4 hands available 253-539-5644
# ['4']
# grand open sweet girls free table shower ! 2 girls 4 hands available 253-539-5644

# %%
print(len(list(test_dict.keys())))
test_dict
# Out:
# 1
# {"b'000933C0D6D4007511B1473E84CF086EF23CB1181AD09182572E8796A2749434'": {'id': "b'000933C0D6D4007511B1473E84CF086EF23CB1181AD09182572E8796A2749434'",
#   'price/hour': ['$80'],
#   'text': '- new mixed caramel beauty bo0bies & bo0ty $80 hh available now. - 20'}}

# %% [markdown]
# ### Testing Functions

# %%
def right_ngrams_price_filter(cand):
    #lst = [,'hr','hour']
    price_terms =["hr","hour","/hr",'hour','$hour',"hourly","h", "$h","/hour"]
    #time_term = [15]
    #$hh'
    half_terms = ["half", "hh",'$hh','hlf','hhr',"halfhour"]
    right_tokens =list(get_right_tokens(cand, window=2))
    left_tokens = list(get_left_tokens(cand, window=2))
    
    
    if cand[0].get_span()[-1] in ['5','0']:
        if len(list(set(price_terms) & set(right_tokens)))>0 or len(list(set(price_terms) & set(left_tokens)))>0:
            if len(list(set(half_terms) & set(right_tokens)))==0:
                if len(list(set(half_terms) & set(left_tokens)))==0:
                    return True
    
    return False
#################################################################      
# def ngrams_halfhour_price_filter(cand):
#     #lst = [,'hr','hour']
#     price_terms =["hr","/hr","hour",'$hour,"hourly", "h", "$h","/hour']
#     #time_term = [15]
#     #$hh'
#     half_terms = ["half", "hh",'$hh','hlf','hhr',"halfhour"]
#     right_tokens =list(get_right_tokens(cand, window=2))
#     left_tokens = list(get_left_tokens(cand, window=2))
    
    
#     if cand[0].get_span()[-1] in ['5','0']:
#         if len(list(set(half_terms) & set(right_tokens)))>0 or len(list(set(half_terms) & set(left_tokens)))>0:
#             if len(list(set(price_terms) & set(right_tokens)))==0:
#                 if len(list(set(price_terms) & set(left_tokens)))==0:
#                     return True
    
#     return False
###############################################################

# %%
train_cands = session.query(candidate_class).filter(candidate_class.split == 0).all()

from snorkel.lf_helpers import (
    get_left_tokens, get_right_tokens, get_between_tokens,
    get_text_between, get_tagged_text)
half_term = ["half", "hh",'$hh','hlf','hhr']
for i, c in enumerate(train_cand):
    name = c[0].get_span().lower().split()
    name_1 = c[0].get_parent().text.lower()
    #right_tokens =list(get_right_tokens(c[0], window=4))
    r = right_ngrams_price_filter(c)
    
    if r:
        left_tokens = list(get_left_tokens(c, window=2))
        
        right_tokens = list(get_right_tokens(c, window=2))
#         for h in half_term:
        if 'half' not in right_tokens:
        #if len(list(set(half_term) & set(left_tokens)))<0:
            print (c)
            print("candidate:",name)
            print(" ")
            print("get parent words:", name_1)
        
            print ( " left_tokens:",left_tokens)
            print ( " right_tokens:",right_tokens)
            print(" ")
            print(" ")
    #print (right_tokens)
        #print(r)
# Out:
# Price(Span("b'100'", sentence=4430698, chars=[99,101], words=[17,17]))
# candidate: ['100']
#
# get parent words: title arriving soon fetishes of all kinds not the law, non smoker and drug free,donations start at 100 hr - 102 - a sexy service com
#  left_tokens: ['start', 'at']
#  right_tokens: ['hr', '-']
#
#
# Price(Span("b'100'", sentence=4430744, chars=[94,96], words=[15,15]))
# candidate: ['100']
#
# get parent words: arriving soon. fetishes of all kinds.not the law, non smoker and drug free,donations start at 100 hr - 102
#  left_tokens: ['start', 'at']
#  right_tokens: ['hr', '-']
#
#
# Price(Span("b'$60'", sentence=2469227, chars=[27,29], words=[5,5]))
# candidate: ['$60']
#
# get parent words: special with cash one hour $60
#  left_tokens: ['one', 'hour']
#  right_tokens: []
#
#
# Price(Span("b'200'", sentence=3730554, chars=[293,295], words=[49,49]))
# candidate: ['200']
#
# get parent words: hey guys i am available for companionship all night. i am100 percent real and ready to spend time with you. i onlyschedule appointments with upscale wealthy gentleman.i am currently only doing incalls in taos. donations for my time are 100 roses for a quick visit(15 minutes)150 half hour and 200 hour. i prefer text but you may also call 505 539 0598.
#  left_tokens: ['hour', 'and']
#  right_tokens: ['hour.', 'i']
#
#
# Price(Span("b'110'", sentence=1232574, chars=[43,45], words=[9,9]))
# candidate: ['110']
#
# get parent words: i need to help with my education. i charge 110 per hour with gfe service.
#  left_tokens: ['i', 'charge']
#  right_tokens: ['per', 'hour']
#
#
# Price(Span("b'$200'", sentence=3034441, chars=[17,20], words=[3,3]))
# candidate: ['$200']
#
# get parent words: mobile service : $200 / h make an appointment 0426 080 157 zac
#  left_tokens: ['service', ':']
#  right_tokens: ['/', 'h']
#
#
# Price(Span("b'160'", sentence=4862620, chars=[24,26], words=[5,5]))
# candidate: ['160']
#
# get parent words: 100 20mins , 120 30mins 160 hr
#  left_tokens: ['120', '30mins']
#  right_tokens: ['hr']
#
#
# Price(Span("b'$60'", sentence=5068595, chars=[25,27], words=[4,4]))
# candidate: ['$60']
#
# get parent words: table shower massage now $60 an hour gorgeous girls
#  left_tokens: ['massage', 'now']
#  right_tokens: ['an', 'hour']
#
#
# Price(Span("b'45'", sentence=2621166, chars=[76,77], words=[9,9]))
# candidate: ['45']
#
# get parent words: url springfieldmo backpage therapeuticmassage two new girls arrived specail 45 hr massage 417 351 5155 21093177.
#  left_tokens: ['arrived', 'specail']
#  right_tokens: ['hr', 'massage']
#
#
# Price(Span("b'200'", sentence=3797759, chars=[113,115], words=[24,24]))
# candidate: ['200']
#
# get parent words: looking to have a great time you will not be disapointed my quick visit is a special for 80$ 100$ for hhr and hr 200 and please dont not ask me for pics i love white men hispanic men i prefer calls instead of texting 423-212-5027.. see my menu of services on my profile before calling...
#  left_tokens: ['and', 'hr']
#  right_tokens: ['and', 'please']
#
#
# Price(Span("b'200'", sentence=3166950, chars=[108,110], words=[21,21]))
# candidate: ['200']
#
# get parent words: respectable gentleman only i love fetishes no a.a sorry my donations are for my time only qv 80 hh 140 hour 200 346-715-4358 call me beauty .
#  left_tokens: ['140', 'hour']
#  right_tokens: ['346-715-4358', 'call']
#
#
# Price(Span("b'$100'", sentence=1763267, chars=[118,121], words=[23,23]))
# candidate: ['$100']
#
# get parent words: hey fellas come and celebrate with me im sweet and sexy and very tasty.im having a new years special for hhr $80 hour $100 all you have to do is call thats all and i promise this will be the best new year for you ever also i am very discreet you will feel like your in heaven please make sure you have read everything before calling
#  left_tokens: ['$80', 'hour']
#  right_tokens: ['all', 'you']
#
#
# Price(Span("b'120'", sentence=3100811, chars=[128,130], words=[24,24]))
# candidate: ['120']
#
# get parent words: come enjoy a relaxing bodyrub from a sexy petite red head names aspen that will have u coming back for more todays spwcuals are 120 hr or 80 half hr txt 9099921451 to make an appointment serious clients only please
#  left_tokens: ['spwcuals', 'are']
#  right_tokens: ['hr', 'or']
#
#
# Price(Span("b'$200'", sentence=4352804, chars=[42,45], words=[7,7]))
# candidate: ['$200']
#
# get parent words: couples- $110 for 30mins $160 for 45mins, $200 1 hour specialty massages start at $140 hr showers $100 30mins
#  left_tokens: ['for', '45mins,']
#  right_tokens: ['1', 'hour']
#
#
# Price(Span("b'$100'", sentence=4352804, chars=[98,101], words=[17,17]))
# candidate: ['$100']
#
# get parent words: couples- $110 for 30mins $160 for 45mins, $200 1 hour specialty massages start at $140 hr showers $100 30mins
#  left_tokens: ['hr', 'showers']
#  right_tokens: ['30mins']
#
#
# Price(Span("b'$140'", sentence=4352804, chars=[82,85], words=[14,14]))
# candidate: ['$140']
#
# get parent words: couples- $110 for 30mins $160 for 45mins, $200 1 hour specialty massages start at $140 hr showers $100 30mins
#  left_tokens: ['start', 'at']
#  right_tokens: ['hr', 'showers']
#
#
# Price(Span("b'$75'", sentence=4352822, chars=[12,14], words=[2,2]))
# candidate: ['$75']
#
# get parent words: lessons are $75 hr or $130 hr 4022590441 i do not set appointments via text. tipping is appreciated not required
#  left_tokens: ['lessons', 'are']
#  right_tokens: ['hr', 'or']
#
#
# Price(Span("b'$130'", sentence=4352822, chars=[22,25], words=[5,5]))
# candidate: ['$130']
#
# get parent words: lessons are $75 hr or $130 hr 4022590441 i do not set appointments via text. tipping is appreciated not required
#  left_tokens: ['hr', 'or']
#  right_tokens: ['hr', '4022590441']
#
#
# Price(Span("b'$145'", sentence=4352871, chars=[25,28], words=[5,5]))
# candidate: ['$145']
#
# get parent words: $100 30min body slide or $145 hr
#  left_tokens: ['slide', 'or']
#  right_tokens: ['hr']
#
#
# Price(Span("b'$135'", sentence=4352886, chars=[22,25], words=[4,4]))
# candidate: ['$135']
#
# get parent words: daily warm up special $135 hr body to body
#  left_tokens: ['up', 'special']
#  right_tokens: ['hr', 'body']
#
#
# Price(Span("b'40'", sentence=4702170, chars=[49,50], words=[6,6]))
# candidate: ['40']
#
# get parent words: url queens backpage therapeuticmassage new stuff 40 hr including table shower best relaxation 92599213.
#  left_tokens: ['new', 'stuff']
#  right_tokens: ['hr', 'including']
#
#
# Price(Span("b'180'", sentence=3065825, chars=[346,348], words=[64,64]))
# candidate: ['180']
#
# get parent words: lexxxi here, are you looking 4 a great time with an amazing girl? then, youve found the girl youve been searching 4.. long day? needing you time? come relax & enjoy some time with me, i guarantee you wont be disappointed. i have great reviews, & love 2 make people smile. if im what your lookin 4 call or text lexxxi @: (513)687-8773. donations: 180 hour 140 half hour incall only no explicit coversation no endless text no black men no law enforcement
#  left_tokens: ['(513)687-8773.', 'donations:']
#  right_tokens: ['hour', '140']
#
#
# Price(Span("b'70'", sentence=634544, chars=[69,70], words=[10,10]))
# candidate: ['70']
#
# get parent words: title private massage service,certified 4 qualified masseuse hh 50 h 70 release donation free - fayetteville therapeutic massage - backpage com
#  left_tokens: ['50', 'h']
#  right_tokens: ['release', 'donation']
#
#
# Price(Span("b'70'", sentence=634558, chars=[63,64], words=[8,8]))
# candidate: ['70']
#
# get parent words: private massage service,certified 4 qualified masseuse.hh 50 h 70 release donation free
#  left_tokens: ['50', 'h']
#  right_tokens: ['release', 'donation']
#
#
# Price(Span("b'50'", sentence=634558, chars=[58,59], words=[6,6]))
# candidate: ['50']
#
# get parent words: private massage service,certified 4 qualified masseuse.hh 50 h 70 release donation free
#  left_tokens: ['qualified', 'masseuse.hh']
#  right_tokens: ['h', '70']
#
#
# Price(Span("b'70'", sentence=634723, chars=[110,111], words=[14,14]))
# candidate: ['70']
#
# get parent words: url fayettevillenc backpage therapeuticmassage private massage service certified 4 qualified masseuse hh 50 h 70 release donation free 31344410.
#  left_tokens: ['50', 'h']
#  right_tokens: ['release', 'donation']
#
#
# Price(Span("b'200'", sentence=4779369, chars=[322,324], words=[62,62]))
# candidate: ['200']
#
# get parent words: im a straight black male with a big black cock just for you. im clear of stds with medical proof, im also fit and in good shape. i only have sex with women. men are not welcomed to view or participate in my sexually activities with women. unless the wife/girl friend wants their partner to be present. it will be an extra 200 per hour and i will wear a mask if pictures or video recordings are taken.
#  left_tokens: ['an', 'extra']
#  right_tokens: ['per', 'hour']
#
#
# Price(Span("b'80'", sentence=3342192, chars=[352,353], words=[65,65]))
# candidate: ['80']
#
# get parent words: $50 qv $80 hhr shayla thick n all da right places lets play - 25 for those men who deserve the best shayla 6784287034 spoil yourself a little. take a break from lifes stresses time with me & my amazing certified skills will leave you craving more i promise, youll love me upscale effortlessly beautiful no bs/no drama. incalls only no outs. qk 50 h/hr 80 hr 200
#  left_tokens: ['50', 'h/hr']
#  right_tokens: ['hr', '200']
#
#
# Price(Span("b'200'", sentence=3342192, chars=[358,360], words=[67,67]))
# candidate: ['200']
#
# get parent words: $50 qv $80 hhr shayla thick n all da right places lets play - 25 for those men who deserve the best shayla 6784287034 spoil yourself a little. take a break from lifes stresses time with me & my amazing certified skills will leave you craving more i promise, youll love me upscale effortlessly beautiful no bs/no drama. incalls only no outs. qk 50 h/hr 80 hr 200
#  left_tokens: ['80', 'hr']
#  right_tokens: []
#
#
# Price(Span("b'$160'", sentence=2414360, chars=[34,37], words=[7,7]))
# candidate: ['$160']
#
# get parent words: i am at a southside edmonton spa. $160 hr and up .
#  left_tokens: ['edmonton', 'spa.']
#  right_tokens: ['hr', 'and']
#
#
# Price(Span("b'$250'", sentence=3023145, chars=[53,56], words=[11,11]))
# candidate: ['$250']
#
# get parent words: we are the only agency open all night garden of eden $250 hr all day - 19
#  left_tokens: ['of', 'eden']
#  right_tokens: ['hr', 'all']
#
#
# Price(Span("b'$500'", sentence=3023160, chars=[19,22], words=[4,4]))
# candidate: ['$500']
#
# get parent words: $500 2 girls /hour $500 only at garden of eden - 19
#  left_tokens: ['girls', '/hour']
#  right_tokens: ['only', 'at']
#
#
# Price(Span("b'60'", sentence=4855352, chars=[42,43], words=[4,4]))
# candidate: ['60']
#
# get parent words: url pensacola backpage therapeuticmassage 60 1 hour grand opening popular spa 850 439 5332 10214781.
#  left_tokens: ['backpage', 'therapeuticmassage']
#  right_tokens: ['1', 'hour']
#
#
# Price(Span("b'160'", sentence=3021544, chars=[0,2], words=[0,0]))
# candidate: ['160']
#
# get parent words: 160 hour visit with kenzy b4 11pm message asap
#  left_tokens: []
#  right_tokens: ['hour', 'visit']
#
#
# Price(Span("b'80'", sentence=1848987, chars=[171,172], words=[37,37]))
# candidate: ['80']
#
# get parent words: hi im very sexy girl i love to party meet nice new friends and try and see new things im always looking foward to an adventure call me if your up for one to im short stay 80 hhr100 hr 200 4157562939. see my menu of services on my profile before calling...
#  left_tokens: ['short', 'stay']
#  right_tokens: ['hhr100', 'hr']
#
#
# Price(Span("b'200'", sentence=1848987, chars=[184,186], words=[40,40]))
# candidate: ['200']
#
# get parent words: hi im very sexy girl i love to party meet nice new friends and try and see new things im always looking foward to an adventure call me if your up for one to im short stay 80 hhr100 hr 200 4157562939. see my menu of services on my profile before calling...
#  left_tokens: ['hhr100', 'hr']
#  right_tokens: ['4157562939.', 'see']
#
#
# Price(Span("b'$120'", sentence=4975701, chars=[79,82], words=[19,19]))
# candidate: ['$120']
#
# get parent words: hi iam ready show you a good time iam available 24-7 my hh is $80 and my hr is $120 - 26
#  left_tokens: ['hr', 'is']
#  right_tokens: ['-', '26']
#
#
# Price(Span("b'30'", sentence=3448545, chars=[80,81], words=[13,13]))
# candidate: ['30']
#
# get parent words: then if u are after something more intense xtra intimate ..is.....295 hour gets 30 mins free til 1pm or 295 gets 15 mins free if u like the rest of that half hr it will b additional $70/.or take two2 hours gets -1 hour 15 mins free added
#  left_tokens: ['hour', 'gets']
#  right_tokens: ['mins', 'free']
#
#
# Price(Span("b'15'", sentence=3448545, chars=[219,220], words=[44,44]))
# candidate: ['15']
#
# get parent words: then if u are after something more intense xtra intimate ..is.....295 hour gets 30 mins free til 1pm or 295 gets 15 mins free if u like the rest of that half hr it will b additional $70/.or take two2 hours gets -1 hour 15 mins free added
#  left_tokens: ['-1', 'hour']
#  right_tokens: ['mins', 'free']
#
#
# Price(Span("b'$120'", sentence=5202600, chars=[79,82], words=[19,19]))
# candidate: ['$120']
#
# get parent words: hi iam ready show you a good time iam available 24-7 my hh is $80 and my hr is $120 - 26
#  left_tokens: ['hr', 'is']
#  right_tokens: ['-', '26']
# Price(Span("b'65'", sentence=5021289, chars=[43,44], words=[5,5]))
# candidate: ['65']
#
# get parent words: url calgary backpage ca therapeuticmassage 65 hour at elite massage_ 5 masseuse waiting for you 15560696.
#  left_tokens: ['ca', 'therapeuticmassage']
#  right_tokens: ['hour', 'at']
#
#
# Price(Span("b'50'", sentence=1191820, chars=[15,16], words=[3,3]))
# candidate: ['50']
#
# get parent words: special only $ 50 per hour fancy beautiful asian spa hauppauge 631.626.0400
#  left_tokens: ['only', '$']
#  right_tokens: ['per', 'hour']
#
#
# Price(Span("b'40'", sentence=4512812, chars=[41,42], words=[4,4]))
# candidate: ['40']
#
# get parent words: url colorado backpage therapeuticmassage 40 1 hr massage englewood on hampden and pearl new young girl 720 216 3708 17625435.
#  left_tokens: ['backpage', 'therapeuticmassage']
#  right_tokens: ['1', 'hr']
#
#
# Price(Span("b'250'", sentence=3126572, chars=[425,427], words=[87,87]))
# candidate: ['250']
#
# get parent words: hello, my name is rachelle and i am visiting mississauga for a few day. please call for details. i truly dislike texting. if you enjoy hanging out with a real doll that is smart, funny and oh so sexy then look no further. i love to experience all i can and share with you. i am 5 4, i weigh 115 lbs. tight smooth and oh so fit. < you must call to book an appointment with me.rachelle 1- 403- 629 - 0040 150 half hour200 hour 250 hour outcall.call
#  left_tokens: ['hour200', 'hour']
#  right_tokens: ['hour', 'outcall.call']

# %% [markdown]
# Add gold labels.

# %%
# from dataset_utils import get_gold_labels_from_meta

# # Adding dev gold labels using dictionary
# %time missed_dev = get_gold_labels_from_meta(session, candidate_class, extraction_type, 1, annotator='gold', gold_dict=None)

# # Adding test gold labels using dictionary
# %time missed_test = get_gold_labels_from_meta(session, candidate_class, extraction_type, 2, annotator='gold', gold_dict=None)

# %%
# # Checking percent of gold labels that are positive
# from dataset_utils import check_gold_perc
# perc_pos = check_gold_perc(session)

# %%
# from dataset_utils import remove_gold_labels
# # Remove gold labels if you want -- uncomment!
# #remove_gold_labels(session)
